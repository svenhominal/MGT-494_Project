# %%
import pandas as pd
import numpy as np

# %%
df =  pd.read_stata("data_regressions_passthrough.dta")
df
# Out:
#          year  month   day  hour  mg_price  eprice    coal     gas   brent  \
# 0      2004.0    1.0   1.0     1     28.99    0.00  0.6668  1.3055  1.7566
# 1      2004.0    1.0   1.0     2     28.23    0.00  0.6668  1.3055  1.7566
# 2      2004.0    1.0   1.0     3     25.48    0.00  0.6668  1.3055  1.7566
# 3      2004.0    1.0   1.0     4     23.00    0.00  0.6668  1.3055  1.7566
# 4      2004.0    1.0   1.0     5     16.54    0.00  0.6668  1.3055  1.7566
# ...       ...    ...   ...   ...       ...     ...     ...     ...     ...
# 30643  2007.0    6.0  30.0    20     31.60    0.14  0.7288  1.4082  4.0270
# 30644  2007.0    6.0  30.0    21     31.62    0.14  0.7288  1.4082  4.0270
# 30645  2007.0    6.0  30.0    22     35.00    0.14  0.7288  1.4082  4.0270
# 30646  2007.0    6.0  30.0    23     40.07    0.14  0.7288  1.4082  4.0270
# 30647  2007.0    6.0  30.0    24     35.00    0.14  0.7288  1.4082  4.0270
#
# ...

# %%
mtx = np.array([df[i] for i in ['windx', 'windx2', 'temp', 'tempx', 'humid', 'coal', 'gas', 'brent',]])
np.linalg.matrix_rank(mtx)
# Out:
# 8
